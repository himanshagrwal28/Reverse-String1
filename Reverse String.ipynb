# %%
# 1. Reverse the string using for loop

# %%
def reverse_string(input_string: str) -> str:
    """
    Function to reverse a given string using for loop.
    Args:
        input_str(str):The string to be reversed.
    Returns:
        str: The reversed version of input string.
    Raises:
        TypeError: If input is not a string.
    """
    # Validate the input type
    if not isinstance(input_string,str):
         raise TypeError("Input must be a string")
    reversed_str = ""
    for char in input_string:
         reversed_str = char + reversed_str
    return reversed_str
# ----Main Execution-----
if __name__ == "__main__":
    try:
         #Taking input from the user
        user_input = input("Enter your string to get reversed : ")
        #calling the function
        result = reverse_string(user_input)
        #Display the reversed string
        print(f" Reversed string :{result}")
    except TypeError  as e:
        print(e)
    except Exception as e:
        print(e)
# Out:
# Enter your string to get reversed :  Hello Himanshu
#  Reversed string :uhsnamiH olleH
